# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
radiomics_df = pd.read_excel('OpenBTAI_RADIOMICS.xlsx')
morphological_df = pd.read_excel('OpenBTAI_MORPHOLOGICAL_MEASUREMENTS.xlsx')
clinical_data_df = pd.read_excel('OpenBTAI_METS_ClinicalData_Sept2023.xlsx')

# %%
# Function for basic EDA
def basic_eda(df, title):
    print(f"--- {title} ---")
    print("Shape of the dataset:", df.shape)
    print("\nColumns:\n", df.columns)
    print("\nData Types:\n", df.dtypes)
    print("\nMissing Values:\n", df.isnull().sum())
    print("\nBasic Statistics:\n", df.describe(include='all'))
    print("\nFirst Few Rows:\n", df.head())
    print("\n--- End of EDA ---\n")
    print("\n")

# %%
# Perform EDA on each dataset
basic_eda(radiomics_df, "Radiomics Dataset")
basic_eda(morphological_df, "Morphological Measurements Dataset")
basic_eda(clinical_data_df, "Clinical Data Dataset")
# Out:
# --- Radiomics Dataset ---
# Shape of the dataset: (1276, 1159)
#
# Columns:
#  Index(['Patient', 'Timepoint', 'Label', 'Lesion', 'Segment', 'Image', 'Mask',
#        'diagnostics_Configuration_EnabledImageTypes',
#        'diagnostics_Configuration_Settings',
#        'diagnostics_Image-original_Dimensionality',
#        ...
#        'wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis',
#        'wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis',
#        'wavelet-LLL_glszm_ZoneEntropy', 'wavelet-LLL_glszm_ZonePercentage',
#        'wavelet-LLL_glszm_ZoneVariance', 'wavelet-LLL_ngtdm_Busyness',
#        'wavelet-LLL_ngtdm_Coarseness', 'wavelet-LLL_ngtdm_Complexity',
#        'wavelet-LLL_ngtdm_Contrast', 'wavelet-LLL_ngtdm_Strength'],
#       dtype='object', length=1159)
#
# Data Types:
#  Patient                           int64
# Timepoint                         int64
# Label                             int64
# Lesion                            int64
# Segment                          object
#                                  ...
# wavelet-LLL_ngtdm_Busyness      float64
# wavelet-LLL_ngtdm_Coarseness    float64
# wavelet-LLL_ngtdm_Complexity    float64
# wavelet-LLL_ngtdm_Contrast      float64
# wavelet-LLL_ngtdm_Strength      float64
# Length: 1159, dtype: object
#
# Missing Values:
#  Patient                         0
# Timepoint                       0
# Label                           0
# Lesion                          0
# Segment                         0
#                                ..
# wavelet-LLL_ngtdm_Busyness      0
# wavelet-LLL_ngtdm_Coarseness    0
# wavelet-LLL_ngtdm_Complexity    0
# wavelet-LLL_ngtdm_Contrast      0
# wavelet-LLL_ngtdm_Strength      0
# Length: 1159, dtype: int64
#
# Basic Statistics:
#               Patient     Timepoint        Label       Lesion  \
# count    1276.000000  1.276000e+03  1276.000000  1276.000000
# unique           NaN           NaN          NaN          NaN
# top              NaN           NaN          NaN          NaN
# freq             NaN           NaN          NaN          NaN
# mean    29546.568182  1.900906e+07    23.256270     2.242947
# std     13670.993253  1.030602e+04    17.545486     1.759832
# min     10005.000000  1.900010e+07    10.000000     1.000000
# 25%     10067.000000  1.900091e+07    11.000000     1.000000
# 50%     40027.000000  1.901021e+07    20.000000     2.000000
# 75%     40116.000000  1.901103e+07    30.000000     3.000000
# max     40185.000000  1.907072e+07    91.000000     9.000000
#
#                    Segment                                   Image  \
# count                 1276                                    1276
# unique                   3                                     293
# top     Contrast-enhancing  10020_19011216_TRA_3D_T1_HR+GD_img.nii
# freq                   499                                      20
# mean                   NaN                                     NaN
# std                    NaN                                     NaN
# min                    NaN                                     NaN
# 25%                    NaN                                     NaN
# 50%                    NaN                                     NaN
# 75%                    NaN                                     NaN
# max                    NaN                                     NaN
#
#                                           Mask  \
# count                                     1276
# unique                                     586
# top     10020_19011216_TRA_3D_T1_HR+GD_msk.nii
# freq                                        13
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#               diagnostics_Configuration_EnabledImageTypes  \
# count                                                1276
# unique                                                  1
# top     {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# freq                                                 1276
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        diagnostics_Configuration_Settings  \
# count                                                1276
# unique                                                 29
# top     {'minimumROIDimensions': 2, 'minimumROISize': ...
# freq                                                  228
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        diagnostics_Image-original_Dimensionality  ...  \
# count                                       1276  ...
# unique                                         1  ...
# top                                           3D  ...
# freq                                        1276  ...
# mean                                         NaN  ...
# std                                          NaN  ...
# min                                          NaN  ...
# 25%                                          NaN  ...
# 50%                                          NaN  ...
# 75%                                          NaN  ...
# max                                          NaN  ...
#
#        wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis  \
# count                                       1276.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                        4654.416849
# std                                         5418.002833
# min                                           11.573413
# 25%                                         1217.810140
# 50%                                         2755.452532
# 75%                                         6170.891498
# max                                        47639.791028
#
#         wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis  \
# count                                       1276.000000
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# mean                                           0.010786
# std                                            0.027340
# min                                            0.000035
# 25%                                            0.000729
# 50%                                            0.002598
# 75%                                            0.009076
# max                                            0.347801
#
#         wavelet-LLL_glszm_ZoneEntropy  wavelet-LLL_glszm_ZonePercentage  \
# count                     1276.000000                       1276.000000
# unique                            NaN                               NaN
# top                               NaN                               NaN
# freq                              NaN                               NaN
# mean                         6.870724                          0.783839
# std                          1.217891                          0.103623
# min                          1.584963                          0.279974
# 25%                          6.317255                          0.733226
# 50%                          7.073232                          0.803130
# 75%                          7.734672                          0.852544
# max                          9.072731                          1.000000
#
#        wavelet-LLL_glszm_ZoneVariance wavelet-LLL_ngtdm_Busyness  \
# count                     1276.000000                1276.000000
# unique                            NaN                        NaN
# top                               NaN                        NaN
# freq                              NaN                        NaN
# mean                         4.900227                   0.087228
# std                         58.859198                   0.172611
# min                          0.000000                   0.004163
# 25%                          0.241024                   0.023755
# 50%                          0.386292                   0.044678
# 75%                          0.767361                   0.089042
# max                       1601.968184                   3.586177
#
#        wavelet-LLL_ngtdm_Coarseness wavelet-LLL_ngtdm_Complexity  \
# count                   1276.000000                 1.276000e+03
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                       0.017832                 1.249989e+05
# std                        0.040013                 1.776538e+05
# min                        0.000115                 1.156007e+01
# 25%                        0.001573                 1.568329e+04
# 50%                        0.005136                 5.427091e+04
# 75%                        0.017325                 1.605669e+05
# max                        0.500000                 1.403448e+06
#
#        wavelet-LLL_ngtdm_Contrast wavelet-LLL_ngtdm_Strength
# count                 1276.000000                1276.000000
# unique                        NaN                        NaN
# top                           NaN                        NaN
# freq                          NaN                        NaN
# mean                     1.891934                  39.800447
# std                      4.147563                  38.151881
# min                      0.061269                   0.287648
# 25%                      0.520214                  14.440656
# 50%                      0.917055                  29.647932
# 75%                      1.689471                  52.556461
# max                     57.763284                 351.729554
#
# [11 rows x 1159 columns]
#
# First Few Rows:
#     Patient  Timepoint  Label  Lesion             Segment  \
# 0    10005   19010618     11       1  Contrast-enhancing
# 1    10005   19010618     10       1               Total
# 2    10005   19011011     11       1  Contrast-enhancing
# 3    10005   19011011     10       1               Total
# 4    10005   19011011     31       3  Contrast-enhancing
#
#                                  Image                                   Mask  \
# 0  10005_19010618_eTRA-3D-T1Gd_img.nii    10005_19010618_eTRA-3D-T1Gd_msk.nii
# 1  10005_19010618_eTRA-3D-T1Gd_img.nii  10005_19010618_eTRA-3D-T1Gd_Total.nii
# 2  10005_19011011_eTRA-3D-T1Gd_img.nii    10005_19011011_eTRA-3D-T1Gd_msk.nii
# 3  10005_19011011_eTRA-3D-T1Gd_img.nii  10005_19011011_eTRA-3D-T1Gd_Total.nii
# 4  10005_19011011_eTRA-3D-T1Gd_img.nii    10005_19011011_eTRA-3D-T1Gd_msk.nii
#
#          diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 1  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 2  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 3  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
# 4  {'Original': {}, 'LoG': {'sigma': [1.0, 3.0, 5...
#
#                   diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 3  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 4  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#   diagnostics_Image-original_Dimensionality  ...  \
# 0                                        3D  ...
# 1                                        3D  ...
# 2                                        3D  ...
# 3                                        3D  ...
# 4                                        3D  ...
#
#   wavelet-LLL_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                      3567.212785
# 1                                      3567.212785
# 2                                      4717.138734
# 3                                      4717.138734
# 4                                       794.249281
#
#    wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis  \
# 0                                         0.017447
# 1                                         0.017447
# 2                                         0.008230
# 3                                         0.008230
# 4                                         0.005778
#
#    wavelet-LLL_glszm_ZoneEntropy  wavelet-LLL_glszm_ZonePercentage  \
# 0                       6.431822                          0.917647
# 1                       6.431822                          0.917647
# 2                       7.127929                          0.897698
# 3                       7.127929                          0.897698
# 4                       6.084317                          0.812620
#
#   wavelet-LLL_glszm_ZoneVariance wavelet-LLL_ngtdm_Busyness  \
# 0                       0.094510                   0.017957
# 1                       0.094510                   0.017957
# 2                       0.169349                   0.012306
# 3                       0.169349                   0.012306
# 4                       0.257417                   0.032852
#
#   wavelet-LLL_ngtdm_Coarseness wavelet-LLL_ngtdm_Complexity  \
# 0                     0.018676                100134.437382
# 1                     0.018676                100134.437382
# 2                     0.014492                148169.479232
# 3                     0.014492                148169.479232
# 4                     0.018143                 11705.643816
#
#   wavelet-LLL_ngtdm_Contrast wavelet-LLL_ngtdm_Strength
# 0                   6.162393                 164.102161
# 1                   6.162393                 164.102161
# 2                   2.638250                 155.496958
# 3                   2.638250                 155.496958
# 4                   0.387974                  68.059546
#
# [5 rows x 1159 columns]
#
# --- End of EDA ---
#
#
#
# --- Morphological Measurements Dataset ---
# Shape of the dataset: (499, 18)
#
# Columns:
#  Index(['PATIENT', 'TIME POINT', 'PIXELSPACING', 'SBS', 'STH', 'STATION NAME',
#        'REPTIME', 'ECHOTIME', 'MAGNETIC FIELD', 'LESION', 'TOTALVOLUME',
#        'CEVOLUME', 'NECVOLUME', 'CERIMWIDTH', 'MAXDIAMETER3D', 'TOTALSURFACE',
#        'RENDVOLUME', 'SURFACEREGULARITY'],
#       dtype='object')
#
# Data Types:
#  PATIENT                int64
# TIME POINT             int64
# PIXELSPACING         float64
# SBS                  float64
# STH                  float64
# STATION NAME          object
# REPTIME              float64
# ECHOTIME             float64
# MAGNETIC FIELD       float64
# LESION                 int64
# TOTALVOLUME          float64
# CEVOLUME             float64
# NECVOLUME            float64
# CERIMWIDTH           float64
# MAXDIAMETER3D        float64
# TOTALSURFACE         float64
# RENDVOLUME           float64
# SURFACEREGULARITY    float64
# dtype: object
#
# Missing Values:
#  PATIENT              0
# TIME POINT           0
# PIXELSPACING         0
# SBS                  0
# STH                  0
# STATION NAME         0
# REPTIME              0
# ECHOTIME             0
# MAGNETIC FIELD       0
# LESION               0
# TOTALVOLUME          0
# CEVOLUME             0
# NECVOLUME            0
# CERIMWIDTH           0
# MAXDIAMETER3D        0
# TOTALSURFACE         0
# RENDVOLUME           0
# SURFACEREGULARITY    0
# dtype: int64
#
# Basic Statistics:
#               PATIENT    TIME POINT  PIXELSPACING         SBS         STH  \
# count     499.000000  4.990000e+02    499.000000  499.000000  499.000000
# unique           NaN           NaN           NaN         NaN         NaN
# top              NaN           NaN           NaN         NaN         NaN
# freq             NaN           NaN           NaN         NaN         NaN
# mean    29130.603206  1.900930e+07      0.627014    1.103784    1.492084
# std     13814.749515  1.047440e+04      0.224671    0.255037    0.445304
# min     10005.000000  1.900010e+07      0.390625    0.491830    1.000000
# 25%     10064.000000  1.900087e+07      0.449219    1.000000    1.300000
# 50%     40027.000000  1.901030e+07      0.500000    1.000003    1.300000
# 75%     40116.000000  1.901103e+07      0.976562    1.300000    1.600000
# max     40185.000000  1.907072e+07      1.015600    2.000000    4.000000
#
#                    STATION NAME     REPTIME    ECHOTIME  MAGNETIC FIELD  \
# count                       499  499.000000  499.000000      499.000000
# unique                        3         NaN         NaN             NaN
# top     Philips Medical Systems         NaN         NaN             NaN
# freq                        197         NaN         NaN             NaN
# mean                        NaN  103.048798    5.895376       31.639279
# std                         NaN  201.613133    3.576990      671.421486
# min                         NaN    5.743400    1.512000        1.000000
# 25%                         NaN   11.000000    3.836000        1.500000
# 50%                         NaN   25.000000    4.760000        1.500000
# 75%                         NaN   25.000000    5.313000        1.500000
# max                         NaN  600.000000   16.743000    15000.000000
#
#             LESION  TOTALVOLUME    CEVOLUME   NECVOLUME  CERIMWIDTH  \
# count   499.000000   499.000000  499.000000  499.000000  499.000000
# unique         NaN          NaN         NaN         NaN         NaN
# top            NaN          NaN         NaN         NaN         NaN
# freq           NaN          NaN         NaN         NaN         NaN
# mean      2.346693     3.003380    2.453379    0.550001    0.413135
# std       1.838359     5.138259    4.019539    1.777595    0.213807
# min       1.000000     0.002314    0.002314    0.000000    0.058940
# 25%       1.000000     0.163114    0.161309    0.000000    0.268487
# 50%       2.000000     0.730593    0.674050    0.014126    0.374594
# 75%       3.000000     3.138256    2.657605    0.282456    0.497631
# max       9.000000    29.405025   25.292145   22.799725    1.348346
#
#         MAXDIAMETER3D  TOTALSURFACE  RENDVOLUME  SURFACEREGULARITY
# count      499.000000    499.000000  499.000000         499.000000
# unique            NaN           NaN         NaN                NaN
# top               NaN           NaN         NaN                NaN
# freq              NaN           NaN         NaN                NaN
# mean         1.805534     11.194605    2.992438           0.650790
# std          1.189654     14.056973    5.132269           0.105145
# min          0.128574      0.072706    0.001488           0.342218
# 25%          0.875762      1.759797    0.156359           0.573883
# 50%          1.517407      5.249957    0.725330           0.661279
# 75%          2.433996     14.712492    3.121172           0.730352
# max          7.266148     81.319582   29.378064           0.872451
#
# First Few Rows:
#     PATIENT  TIME POINT  PIXELSPACING  SBS  STH             STATION NAME  \
# 0    10005    19010618      0.976562  1.0  2.0  Philips Medical Systems
# 1    10005    19011011      0.976562  1.0  2.0  Philips Medical Systems
# 2    10005    19011011      0.976562  1.0  2.0  Philips Medical Systems
# 3    10005    19020128      0.976562  1.0  2.0  Philips Medical Systems
# 4    10005    19020128      0.976562  1.0  2.0  Philips Medical Systems
#
#    REPTIME  ECHOTIME  MAGNETIC FIELD  LESION  TOTALVOLUME  CEVOLUME  \
# 0     25.0     5.139             1.5       1     0.162125  0.162125
# 1     25.0     4.962             1.5       1     0.372887  0.372887
# 2     25.0     4.962             1.5       3     1.604080  0.498772
# 3     25.0     5.192             1.5       1     2.336502  2.335548
# 4     25.0     5.192             1.5       3     3.134727  1.180649
#
#    NECVOLUME  CERIMWIDTH  MAXDIAMETER3D  TOTALSURFACE  RENDVOLUME  \
# 0   0.000000    0.338262       0.783567      1.665688    0.154416
# 1   0.000000    0.446508       1.103769      2.967784    0.362992
# 2   1.105309    0.084779       2.214020      8.795319    1.586278
# 3   0.000954    0.762114       1.980714     10.094219    2.316435
# 4   1.954079    0.132334       2.564806     13.813849    3.109892
#
#    SURFACEREGULARITY
# 0           0.763884
# 1           0.755049
# 2           0.646738
# 3           0.768135
# 4           0.644168
#
# --- End of EDA ---
#
#
#
# --- Clinical Data Dataset ---
# Shape of the dataset: (178, 97)
#
# Columns:
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Primary codes', 'Unnamed: 6', 'Breast subtypes', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
#        'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64',
#        'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68',
#        'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72',
#        'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76',
#        'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80',
#        'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84',
#        'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88',
#        'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92',
#        'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96'],
#       dtype='object')
#
# Data Types:
#  Unnamed: 0     object
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
#                 ...
# Unnamed: 92    object
# Unnamed: 93    object
# Unnamed: 94    object
# Unnamed: 95    object
# Unnamed: 96    object
# Length: 97, dtype: object
#
# Missing Values:
#  Unnamed: 0     13
# Unnamed: 1     17
# Unnamed: 2     15
# Unnamed: 3     35
# Unnamed: 4     16
#                ..
# Unnamed: 92    17
# Unnamed: 93    17
# Unnamed: 94    17
# Unnamed: 95    17
# Unnamed: 96    17
# Length: 97, dtype: int64
#
# Basic Statistics:
#         Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# count         165         161         163         143         162
# unique         80          37           5          11          11
# top        010020          64           1           1           1
# freq            7          13         107          42          69
#
#         Primary codes  Unnamed: 6  Breast subtypes  Unnamed: 8  Unnamed: 9  \
# count             173         130               56          38           6
# unique             20           7               13           2           2
# top                 2           1                0           0           0
# freq               85          73               42          37           5
#
#         ...  Unnamed: 87 Unnamed: 88 Unnamed: 89 Unnamed: 90  Unnamed: 91  \
# count   ...          159         151         139         140          161
# unique  ...           13           9           5           3            3
# top     ...
# freq    ...          124         130         134         137          158
#
#         Unnamed: 92  Unnamed: 93 Unnamed: 94  Unnamed: 95  Unnamed: 96
# count           161          161         161          161          161
# unique            3            3           3            3            3
# top
# freq            158          158         158          158          158
#
# [4 rows x 97 columns]
#
# First Few Rows:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Primary codes  \
# 0        NaN        NaN        NaN        NaN        NaN     1. Breast
# 1        NaN        NaN        NaN        NaN        NaN      2. NSCLC
# 2        NaN        NaN        NaN        NaN        NaN       3. SCLC
# 3        NaN        NaN        NaN        NaN        NaN   4. Melanoma
# 4        NaN        NaN        NaN        NaN        NaN     5. Kidney
#
#   Unnamed: 6     Breast subtypes Unnamed: 8 Unnamed: 9  ... Unnamed: 87  \
# 0        NaN        1. Luminal a        NaN        NaN  ...         NaN
# 1        NaN        2. Luminal b        NaN        NaN  ...         NaN
# 2        NaN  3. Triple negative        NaN        NaN  ...         NaN
# 3        NaN             4. HER2        NaN        NaN  ...         NaN
# 4        NaN       Lung subtypes        NaN        NaN  ...         NaN
#
#   Unnamed: 88 Unnamed: 89 Unnamed: 90 Unnamed: 91 Unnamed: 92 Unnamed: 93  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 94 Unnamed: 95 Unnamed: 96
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 97 columns]
#
# --- End of EDA ---

# %%
# Visualize missing values using heatmaps
plt.figure(figsize=(16, 6))
plt.subplot(1, 3, 1)
sns.heatmap(radiomics_df.isnull(), cbar=False, cmap="viridis")
plt.title("Radiomics Dataset - Missing Values")

plt.subplot(1, 3, 2)
sns.heatmap(morphological_df.isnull(), cbar=False, cmap="viridis")
plt.title("Morphological Measurements Dataset - Missing Values")

plt.subplot(1, 3, 3)
sns.heatmap(clinical_data_df.isnull(), cbar=False, cmap="viridis")
plt.title("Clinical Data Dataset - Missing Values")

plt.tight_layout()
plt.show()

# Visualize distributions of numerical features (for Radiomics Dataset)
numeric_features_radiomics = radiomics_df.select_dtypes(include=['float64', 'int64']).columns

radiomics_df[numeric_features_radiomics].hist(bins=20, figsize=(14, 10), color='blue')
plt.suptitle('Distribution of Numerical Features - Radiomics Dataset', fontsize=16)
plt.show()

# Visualize distributions of numerical features (for Morphological Measurements Dataset)
numeric_features_morphological = morphological_df.select_dtypes(include=['float64', 'int64']).columns

morphological_df[numeric_features_morphological].hist(bins=20, figsize=(14, 10), color='green')
plt.suptitle('Distribution of Numerical Features - Morphological Measurements Dataset', fontsize=16)
plt.show()

# Visualize distributions of numerical features (for Clinical Data Dataset)
numeric_features_clinical = clinical_data_df.select_dtypes(include=['float64', 'int64']).columns

clinical_data_df[numeric_features_clinical].hist(bins=20, figsize=(14, 10), color='orange')
plt.suptitle('Distribution of Numerical Features - Clinical Data Dataset', fontsize=16)
plt.show()

# Correlation heatmap for each dataset
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.heatmap(radiomics_df[numeric_features_radiomics].corr(), annot=True, cmap="coolwarm")
plt.title("Radiomics Dataset - Correlation Heatmap")

plt.subplot(1, 3, 2)
sns.heatmap(morphological_df[numeric_features_morphological].corr(), annot=True, cmap="coolwarm")
plt.title("Morphological Measurements Dataset - Correlation Heatmap")

plt.subplot(1, 3, 3)
sns.heatmap(clinical_data_df[numeric_features_clinical].corr(), annot=True, cmap="coolwarm")
plt.title("Clinical Data Dataset - Correlation Heatmap")

plt.tight_layout()
plt.show()
